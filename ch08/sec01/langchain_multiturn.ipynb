# %%
# from openai import OpenAI  # 주석처리
# from dotenv import load_dotenv
# import os

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, AIMessage, SystemMessage

# %%
# load_dotenv()
# api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키 가져오기
# client = OpenAI(api_key=api_key)  # 오픈AI 클라이언트의 인스턴스 생성

# %%
llm = ChatOpenAI(model="gpt-5.6-luna")  # ChatOpenAI 클래스의 인스턴스 생성

# %%
# def get_ai_response(messages):
#     response = client.chat.completions.create(
#         model="gpt-5.6-luna",  # 응답 생성에 사용할 모델 지정
#         messages=messages,  # 대화 기록을 입력으로 전달
#     )
#     return response.choices[0].message.content  # 생성된 응답의 내용 반환

# %%
messages = [
    # {"role": "system", "content": "너는 사용자를 도와주는 상담사야."},  # 초기 시스템 메시지
    SystemMessage("너는 사용자를 도와주는 상담사야."),  # 초기 시스템 메시지
]

# %%
while True:
    user_input = input("사용자: ")  # 사용자 입력 받기

    if user_input == "exit":  # ② 사용자가 대화를 종료하려는지 확인인
        break
    
    messages.append(
        # {"role": "user", "content": user_input} # 주석처리
        HumanMessage(user_input)
    )  # 사용자 메시지를 대화 기록에 추가 

    print("사용자: " + user_input)
    
    # ai_response = get_ai_response(messages)  # 주석처리
    ai_response = llm.invoke(messages)  # 대화 기록을 기반으로 AI 응답 가져오기
    messages.append(
        # {"role": "assistant", "content": ai_response} # 주석처리
        ai_response
    )  # AI 응답 대화 기록에 추가하기

    print("AI: " + ai_response.content)  # AI 응답 출력
# Out:
# 사용자: 안녕? 나는 이성용이야
# AI: 안녕하세요, 성용님! 만나서 반가워요. 무엇을 도와드릴까요?
# 사용자: 나에 대해 알고 있는 정보가 있어?
# AI: 현재 대화에서 알게 된 정보는 성용님이 **“이성용”이라고 소개하셨다**는 것뿐이에요.
# 나이, 직업, 거주지 같은 다른 개인정보는 알지 못하며, 성용님이 직접 알려주지 않는 한 추측하지 않아요.

# %% [markdown]
# messages 리스트에 첫 번째 사용자 입력이 HumanMessage("안녕? 나는 이성용이야")로 저장됐기 때문에
#
# 그다음 llm.invoke(messages)를 호출할 때 messages 전체가 모델에 전달되므로, 모델은 이전 대화를 보고 "이성용"이라는 이름을 알 수 있음.
